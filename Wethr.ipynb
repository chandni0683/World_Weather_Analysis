# %%
#Import the Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a set of random latitude and logitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 613

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/chandnisharma/opt/anaconda3/lib/python3.8/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/chandnisharma/opt/anaconda3/lib/python3.8/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bd36c43c91d8> in <module>
#       1 # Starting URL for Weather Map API Call.
# ----> 2 url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#       3 print(url)
#
# NameError: name 'weather_api_key' is not defined

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | port elizabeth
# Processing Record 3 of Set 1 | provideniya
# Processing Record 4 of Set 1 | baykit
# Processing Record 5 of Set 1 | upernavik
# Processing Record 6 of Set 1 | kaeo
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | tasiilaq
# Processing Record 9 of Set 1 | pochutla
# Processing Record 10 of Set 1 | lebu
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | tiksi
# Processing Record 13 of Set 1 | quime
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | chokurdakh
# Processing Record 18 of Set 1 | port lincoln
# Processing Record 19 of Set 1 | tuatapere
# Processing Record 20 of Set 1 | asau
# Processing Record 21 of Set 1 | otane
# Processing Record 22 of Set 1 | kavieng
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | kawalu
# Processing Record 25 of Set 1 | lompoc
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | cockburn town
# Processing Record 30 of Set 1 | taltal
# Processing Record 31 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 1 | cherskiy
# Processing Record 33 of Set 1 | torbay
# Processing Record 34 of Set 1 | huazolotitlan
# City not found. Skipping...
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 1 | kidal
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | georgetown
# Processing Record 42 of Set 1 | hilo
# Processing Record 43 of Set 1 | xiangxiang
# Processing Record 44 of Set 1 | kenai
# Processing Record 45 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 46 of Set 1 | samarai
# Processing Record 47 of Set 1 | halifax
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | daru
# Processing Record 50 of Set 1 | tupik
# Processing Record 1 of Set 2 | safford
# Processing Record 2 of Set 2 | egvekinot
# Processing Record 3 of Set 2 | bereda
# Processing Record 4 of Set 2 | yerbogachen
# Processing Record 5 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 2 | norman wells
# Processing Record 7 of Set 2 | tuktoyaktuk
# Processing Record 8 of Set 2 | mahibadhoo
# Processing Record 9 of Set 2 | ucluelet
# Processing Record 10 of Set 2 | rikitea
# Processing Record 11 of Set 2 | mount isa
# Processing Record 12 of Set 2 | isangel
# Processing Record 13 of Set 2 | codrington
# Processing Record 14 of Set 2 | bogande
# Processing Record 15 of Set 2 | lavrentiya
# Processing Record 16 of Set 2 | kunda
# Processing Record 17 of Set 2 | aswan
# Processing Record 18 of Set 2 | kungurtug
# Processing Record 19 of Set 2 | kahului
# Processing Record 20 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 2 | port hardy
# Processing Record 22 of Set 2 | tumbagaan
# Processing Record 23 of Set 2 | busselton
# Processing Record 24 of Set 2 | nampula
# Processing Record 25 of Set 2 | igarka
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | kodiak
# Processing Record 28 of Set 2 | ozinki
# Processing Record 29 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 2 | nanakuli
# Processing Record 31 of Set 2 | lukovetskiy
# Processing Record 32 of Set 2 | luis correia
# Processing Record 33 of Set 2 | ribeira grande
# Processing Record 34 of Set 2 | eenhana
# Processing Record 35 of Set 2 | flin flon
# Processing Record 36 of Set 2 | kerema
# Processing Record 37 of Set 2 | port macquarie
# Processing Record 38 of Set 2 | buala
# Processing Record 39 of Set 2 | falealupo
# City not found. Skipping...
# Processing Record 40 of Set 2 | pevek
# Processing Record 41 of Set 2 | santiago del estero
# Processing Record 42 of Set 2 | paucartambo
# City not found. Skipping...
# Processing Record 43 of Set 2 | alofi
# Processing Record 44 of Set 2 | kaitangata
# Processing Record 45 of Set 2 | port alfred
# Processing Record 46 of Set 2 | waingapu
# Processing Record 47 of Set 2 | steamboat springs
# Processing Record 48 of Set 2 | ilo
# Processing Record 49 of Set 2 | coquimbo
# Processing Record 50 of Set 2 | barrow
# Processing Record 1 of Set 3 | khatanga
# Processing Record 2 of Set 3 | zhigansk
# Processing Record 3 of Set 3 | san quintin
# Processing Record 4 of Set 3 | nelson bay
# Processing Record 5 of Set 3 | lorengau
# Processing Record 6 of Set 3 | anadyr
# Processing Record 7 of Set 3 | lagoa
# Processing Record 8 of Set 3 | ozgon
# City not found. Skipping...
# Processing Record 9 of Set 3 | san patricio
# Processing Record 10 of Set 3 | neiafu
# Processing Record 11 of Set 3 | sorland
# Processing Record 12 of Set 3 | uray
# Processing Record 13 of Set 3 | castro
# Processing Record 14 of Set 3 | saskylakh
# Processing Record 15 of Set 3 | pisco
# Processing Record 16 of Set 3 | luena
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | atar
# Processing Record 19 of Set 3 | padang
# Processing Record 20 of Set 3 | hambantota
# Processing Record 21 of Set 3 | bambous virieux
# Processing Record 22 of Set 3 | mukhen
# Processing Record 23 of Set 3 | esperance
# Processing Record 24 of Set 3 | teitipac
# Processing Record 25 of Set 3 | sechura
# Processing Record 26 of Set 3 | starosubkhangulovo
# Processing Record 27 of Set 3 | new norfolk
# Processing Record 28 of Set 3 | umm lajj
# Processing Record 29 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 3 | abbeville
# Processing Record 31 of Set 3 | sao goncalo do amarante
# Processing Record 32 of Set 3 | hobart
# Processing Record 33 of Set 3 | east london
# Processing Record 34 of Set 3 | beloha
# Processing Record 35 of Set 3 | saldanha
# Processing Record 36 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 37 of Set 3 | hay river
# Processing Record 38 of Set 3 | flinders
# Processing Record 39 of Set 3 | vaini
# Processing Record 40 of Set 3 | boden
# Processing Record 41 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 3 | prado
# Processing Record 43 of Set 3 | saint-philippe
# Processing Record 44 of Set 3 | sistranda
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | axim
# Processing Record 47 of Set 3 | rockport
# Processing Record 48 of Set 3 | portland
# Processing Record 49 of Set 3 | mopipi
# Processing Record 50 of Set 3 | mattru
# Processing Record 1 of Set 4 | arraial do cabo
# Processing Record 2 of Set 4 | walvis bay
# Processing Record 3 of Set 4 | henties bay
# Processing Record 4 of Set 4 | chuy
# Processing Record 5 of Set 4 | castlegar
# Processing Record 6 of Set 4 | itacare
# Processing Record 7 of Set 4 | fostoria
# Processing Record 8 of Set 4 | avera
# Processing Record 9 of Set 4 | severo-kurilsk
# Processing Record 10 of Set 4 | kapaa
# Processing Record 11 of Set 4 | butaritari
# Processing Record 12 of Set 4 | dikson
# Processing Record 13 of Set 4 | kalmeshwar
# Processing Record 14 of Set 4 | dunedin
# Processing Record 15 of Set 4 | waitati
# Processing Record 16 of Set 4 | kota belud
# Processing Record 17 of Set 4 | shchelyayur
# City not found. Skipping...
# Processing Record 18 of Set 4 | punta de piedra
# Processing Record 19 of Set 4 | pangnirtung
# Processing Record 20 of Set 4 | the valley
# Processing Record 21 of Set 4 | north platte
# Processing Record 22 of Set 4 | puerto quijarro
# Processing Record 23 of Set 4 | horodyshche
# Processing Record 24 of Set 4 | carnarvon
# Processing Record 25 of Set 4 | broken hill
# Processing Record 26 of Set 4 | vanino
# Processing Record 27 of Set 4 | mount gambier
# Processing Record 28 of Set 4 | vanavara
# Processing Record 29 of Set 4 | tilichiki
# Processing Record 30 of Set 4 | viedma
# Processing Record 31 of Set 4 | stuttgart
# Processing Record 32 of Set 4 | narsaq
# Processing Record 33 of Set 4 | hasaki
# Processing Record 34 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 4 | bengkulu
# Processing Record 36 of Set 4 | vila franca do campo
# Processing Record 37 of Set 4 | san carlos de bariloche
# Processing Record 38 of Set 4 | dudinka
# Processing Record 39 of Set 4 | volokolamsk
# Processing Record 40 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 4 | souillac
# Processing Record 42 of Set 4 | saint-joseph
# Processing Record 43 of Set 4 | maniitsoq
# Processing Record 44 of Set 4 | trincomalee
# Processing Record 45 of Set 4 | ulaangom
# Processing Record 46 of Set 4 | ixtapa
# Processing Record 47 of Set 4 | batsfjord
# Processing Record 48 of Set 4 | ausa
# Processing Record 49 of Set 4 | aksu
# Processing Record 50 of Set 4 | hofn
# Processing Record 1 of Set 5 | campobello di mazara
# Processing Record 2 of Set 5 | olga
# Processing Record 3 of Set 5 | mumford
# Processing Record 4 of Set 5 | lata
# Processing Record 5 of Set 5 | dhidhdhoo
# Processing Record 6 of Set 5 | turukhansk
# Processing Record 7 of Set 5 | fergus falls
# Processing Record 8 of Set 5 | maxixe
# Processing Record 9 of Set 5 | mopti
# Processing Record 10 of Set 5 | strezhevoy
# Processing Record 11 of Set 5 | rio grande
# Processing Record 12 of Set 5 | pauini
# Processing Record 13 of Set 5 | leningradskiy
# Processing Record 14 of Set 5 | clyde river
# Processing Record 15 of Set 5 | pitimbu
# Processing Record 16 of Set 5 | el dovio
# Processing Record 17 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 18 of Set 5 | mizan teferi
# Processing Record 19 of Set 5 | batman
# Processing Record 20 of Set 5 | licheng
# Processing Record 21 of Set 5 | panguna
# Processing Record 22 of Set 5 | tateyama
# Processing Record 23 of Set 5 | nikolskoye
# Processing Record 24 of Set 5 | papasquiaro
# City not found. Skipping...
# Processing Record 25 of Set 5 | oyama
# Processing Record 26 of Set 5 | ignacio zaragoza
# Processing Record 27 of Set 5 | oistins
# Processing Record 28 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 29 of Set 5 | acandi
# Processing Record 30 of Set 5 | sakakah
# Processing Record 31 of Set 5 | huangmei
# Processing Record 32 of Set 5 | bandarawela
# Processing Record 33 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 34 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 5 | half moon bay
# Processing Record 36 of Set 5 | namatanai
# Processing Record 37 of Set 5 | huzhou
# Processing Record 38 of Set 5 | karratha
# Processing Record 39 of Set 5 | inirida
# Processing Record 40 of Set 5 | kieta
# Processing Record 41 of Set 5 | shrewsbury
# Processing Record 42 of Set 5 | longyearbyen
# Processing Record 43 of Set 5 | correderos
# Processing Record 44 of Set 5 | basse
# Processing Record 45 of Set 5 | neftcala
# Processing Record 46 of Set 5 | san mateo del mar
# Processing Record 47 of Set 5 | ordzhonikidze
# Processing Record 48 of Set 5 | puerto escondido
# Processing Record 49 of Set 5 | boende
# Processing Record 50 of Set 5 | vestmannaeyjar
# Processing Record 1 of Set 6 | whitehorse
# Processing Record 2 of Set 6 | yeletskiy
# City not found. Skipping...
# Processing Record 3 of Set 6 | shahr-e babak
# Processing Record 4 of Set 6 | katherine
# Processing Record 5 of Set 6 | swellendam
# Processing Record 6 of Set 6 | huacho
# Processing Record 7 of Set 6 | bathsheba
# Processing Record 8 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 9 of Set 6 | thompson
# Processing Record 10 of Set 6 | marfino
# Processing Record 11 of Set 6 | kloulklubed
# Processing Record 12 of Set 6 | cabo san lucas
# Processing Record 13 of Set 6 | elko
# Processing Record 14 of Set 6 | tibu
# Processing Record 15 of Set 6 | cabedelo
# Processing Record 16 of Set 6 | honiton
# Processing Record 17 of Set 6 | vardo
# Processing Record 18 of Set 6 | ler
# Processing Record 19 of Set 6 | acala
# Processing Record 20 of Set 6 | fayaoue
# Processing Record 21 of Set 6 | vanimo
# Processing Record 22 of Set 6 | kutum
# Processing Record 23 of Set 6 | russell
# Processing Record 24 of Set 6 | samoded
# Processing Record 25 of Set 6 | fallon
# Processing Record 26 of Set 6 | bochnia
# Processing Record 27 of Set 6 | fort nelson
# Processing Record 28 of Set 6 | geraldton
# Processing Record 29 of Set 6 | oranjestad
# Processing Record 30 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 6 | comodoro rivadavia
# Processing Record 33 of Set 6 | malmesbury
# Processing Record 34 of Set 6 | sioux lookout
# Processing Record 35 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 6 | sitka
# Processing Record 37 of Set 6 | siniscola
# Processing Record 38 of Set 6 | roald
# Processing Record 39 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 6 | goure
# Processing Record 41 of Set 6 | posta calnau
# Processing Record 42 of Set 6 | kruisfontein
# Processing Record 43 of Set 6 | namibe
# Processing Record 44 of Set 6 | urubicha
# Processing Record 45 of Set 6 | sao joao da barra
# Processing Record 46 of Set 6 | san martin
# Processing Record 47 of Set 6 | nakhon si thammarat
# Processing Record 48 of Set 6 | sarankhola
# Processing Record 49 of Set 6 | yanam
# Processing Record 50 of Set 6 | osa
# Processing Record 1 of Set 7 | ancud
# Processing Record 2 of Set 7 | saint-hyacinthe
# Processing Record 3 of Set 7 | kavaratti
# Processing Record 4 of Set 7 | laguna
# Processing Record 5 of Set 7 | kalangala
# Processing Record 6 of Set 7 | guerrero negro
# Processing Record 7 of Set 7 | road town
# Processing Record 8 of Set 7 | taraz
# Processing Record 9 of Set 7 | victoria
# Processing Record 10 of Set 7 | mar del plata
# Processing Record 11 of Set 7 | kurumkan
# Processing Record 12 of Set 7 | peace river
# Processing Record 13 of Set 7 | fortuna
# Processing Record 14 of Set 7 | jinxiang
# Processing Record 15 of Set 7 | corum
# Processing Record 16 of Set 7 | kamaishi
# Processing Record 17 of Set 7 | meulaboh
# Processing Record 18 of Set 7 | darhan
# Processing Record 19 of Set 7 | esmeraldas
# Processing Record 20 of Set 7 | tarko-sale
# Processing Record 21 of Set 7 | sjovegan
# Processing Record 22 of Set 7 | hashtrud
# Processing Record 23 of Set 7 | makakilo city
# Processing Record 24 of Set 7 | tabuk
# Processing Record 25 of Set 7 | tocopilla
# Processing Record 26 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 7 | itaituba
# Processing Record 28 of Set 7 | maarianhamina
# Processing Record 29 of Set 7 | seguela
# Processing Record 30 of Set 7 | bambanglipuro
# Processing Record 31 of Set 7 | luderitz
# Processing Record 32 of Set 7 | barbastro
# Processing Record 33 of Set 7 | soconusco
# Processing Record 34 of Set 7 | potsdam
# Processing Record 35 of Set 7 | ajdabiya
# Processing Record 36 of Set 7 | ostrovnoy
# Processing Record 37 of Set 7 | mahebourg
# Processing Record 38 of Set 7 | lohardaga
# Processing Record 39 of Set 7 | waterfoot
# Processing Record 40 of Set 7 | longkou
# Processing Record 41 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 42 of Set 7 | doha
# Processing Record 43 of Set 7 | bukachacha
# Processing Record 44 of Set 7 | kindu
# Processing Record 45 of Set 7 | balimo
# City not found. Skipping...
# Processing Record 46 of Set 7 | taoudenni
# Processing Record 47 of Set 7 | altagracia de orituco
# Processing Record 48 of Set 7 | pangkalanbuun
# Processing Record 49 of Set 7 | nzega
# Processing Record 50 of Set 7 | colesberg
# Processing Record 1 of Set 8 | oneonta
# Processing Record 2 of Set 8 | lingao
# Processing Record 3 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 4 of Set 8 | guarda
# Processing Record 5 of Set 8 | zaranj
# Processing Record 6 of Set 8 | ilheus
# Processing Record 7 of Set 8 | ponta do sol
# Processing Record 8 of Set 8 | grindavik
# Processing Record 9 of Set 8 | harlingen
# Processing Record 10 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 11 of Set 8 | beringovskiy
# Processing Record 12 of Set 8 | sangar
# Processing Record 13 of Set 8 | fomboni
# Processing Record 14 of Set 8 | nantucket
# Processing Record 15 of Set 8 | omboue
# Processing Record 16 of Set 8 | natal
# Processing Record 17 of Set 8 | zilair
# Processing Record 18 of Set 8 | eureka
# Processing Record 19 of Set 8 | miles city
# Processing Record 20 of Set 8 | marataizes
# Processing Record 21 of Set 8 | killybegs
# Processing Record 22 of Set 8 | tezu
# Processing Record 23 of Set 8 | bilma
# Processing Record 24 of Set 8 | floro
# Processing Record 25 of Set 8 | naze
# Processing Record 26 of Set 8 | pangai
# Processing Record 27 of Set 8 | ahipara
# Processing Record 28 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 8 | batagay-alyta
# Processing Record 30 of Set 8 | kedrovyy
# Processing Record 31 of Set 8 | necochea
# Processing Record 32 of Set 8 | zeya
# Processing Record 33 of Set 8 | chickasha
# Processing Record 34 of Set 8 | cartagena
# Processing Record 35 of Set 8 | klobuck
# Processing Record 36 of Set 8 | batesville
# Processing Record 37 of Set 8 | duldurga
# Processing Record 38 of Set 8 | talnakh
# Processing Record 39 of Set 8 | ola
# Processing Record 40 of Set 8 | cayenne
# Processing Record 41 of Set 8 | nizhnetroitskiy
# Processing Record 42 of Set 8 | yumen
# Processing Record 43 of Set 8 | marsa matruh
# Processing Record 44 of Set 8 | peruibe
# Processing Record 45 of Set 8 | ekuvukeni
# Processing Record 46 of Set 8 | rio gallegos
# Processing Record 47 of Set 8 | washington
# Processing Record 48 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 49 of Set 8 | severo-yeniseyskiy
# Processing Record 50 of Set 8 | atambua
# Processing Record 1 of Set 9 | tourlaville
# Processing Record 2 of Set 9 | dongying
# Processing Record 3 of Set 9 | pershotravneve
# Processing Record 4 of Set 9 | felidhoo
# City not found. Skipping...
# Processing Record 5 of Set 9 | cidreira
# Processing Record 6 of Set 9 | chinsali
# Processing Record 7 of Set 9 | chimbote
# Processing Record 8 of Set 9 | kyren
# Processing Record 9 of Set 9 | lasa
# Processing Record 10 of Set 9 | havre-saint-pierre
# Processing Record 11 of Set 9 | general roca
# Processing Record 12 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 13 of Set 9 | rome
# Processing Record 14 of Set 9 | nyurba
# Processing Record 15 of Set 9 | radviliskis
# Processing Record 16 of Set 9 | bilibino
# Processing Record 17 of Set 9 | fairbanks
# Processing Record 18 of Set 9 | constitucion
# Processing Record 19 of Set 9 | alghero
# Processing Record 20 of Set 9 | san ignacio
# Processing Record 21 of Set 9 | barranca
# Processing Record 22 of Set 9 | riyadh
# Processing Record 23 of Set 9 | sehithwa
# Processing Record 24 of Set 9 | san-pedro
# Processing Record 25 of Set 9 | vilhena
# Processing Record 26 of Set 9 | kirakira
# Processing Record 27 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 28 of Set 9 | lumphat
# Processing Record 29 of Set 9 | lethem
# Processing Record 30 of Set 9 | saint george
# Processing Record 31 of Set 9 | estepona
# Processing Record 32 of Set 9 | richards bay
# Processing Record 33 of Set 9 | ambon
# Processing Record 34 of Set 9 | caravelas
# Processing Record 35 of Set 9 | praia da vitoria
# Processing Record 36 of Set 9 | carayao
# Processing Record 37 of Set 9 | lalomanu
# City not found. Skipping...
# Processing Record 38 of Set 9 | arman
# Processing Record 39 of Set 9 | margate
# Processing Record 40 of Set 9 | mokrousovo
# Processing Record 41 of Set 9 | huilong
# Processing Record 42 of Set 9 | pontianak
# Processing Record 43 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 44 of Set 9 | angoche
# Processing Record 45 of Set 9 | kartarpur
# Processing Record 46 of Set 9 | jurado
# Processing Record 47 of Set 9 | sao filipe
# Processing Record 48 of Set 9 | salalah
# Processing Record 49 of Set 9 | saint albans
# Processing Record 50 of Set 9 | iracoubo
# Processing Record 1 of Set 10 | kano
# Processing Record 2 of Set 10 | camacha
# Processing Record 3 of Set 10 | gulf gate estates
# Processing Record 4 of Set 10 | venezuela
# Processing Record 5 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 6 of Set 10 | timra
# Processing Record 7 of Set 10 | nanortalik
# Processing Record 8 of Set 10 | byron bay
# Processing Record 9 of Set 10 | oranjemund
# Processing Record 10 of Set 10 | hualmay
# Processing Record 11 of Set 10 | port-gentil
# Processing Record 12 of Set 10 | chara
# Processing Record 13 of Set 10 | khandyga
# Processing Record 14 of Set 10 | itarema
# Processing Record 15 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 10 | bairiki
# Processing Record 17 of Set 10 | bonthe
# Processing Record 18 of Set 10 | arlit
# Processing Record 19 of Set 10 | gazanjyk
# Processing Record 20 of Set 10 | maceio
# Processing Record 21 of Set 10 | verkhnevilyuysk
# Processing Record 22 of Set 10 | hoxter
# City not found. Skipping...
# Processing Record 23 of Set 10 | hanzhong
# Processing Record 24 of Set 10 | luganville
# Processing Record 25 of Set 10 | astana
# Processing Record 26 of Set 10 | coari
# Processing Record 27 of Set 10 | mount pleasant
# Processing Record 28 of Set 10 | haradok
# Processing Record 29 of Set 10 | labuhan
# Processing Record 30 of Set 10 | muncar
# Processing Record 31 of Set 10 | rawson
# Processing Record 32 of Set 10 | antigonish
# Processing Record 33 of Set 10 | adrar
# Processing Record 34 of Set 10 | terney
# Processing Record 35 of Set 10 | bandarbeyla
# Processing Record 36 of Set 10 | etchoropo
# Processing Record 37 of Set 10 | touros
# Processing Record 38 of Set 10 | puerto colombia
# Processing Record 39 of Set 10 | jaisalmer
# Processing Record 40 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 41 of Set 10 | cerrito
# Processing Record 42 of Set 10 | nouadhibou
# Processing Record 43 of Set 10 | eyl
# Processing Record 44 of Set 10 | alice springs
# Processing Record 45 of Set 10 | port blair
# Processing Record 46 of Set 10 | kodinsk
# Processing Record 47 of Set 10 | lithgow
# Processing Record 48 of Set 10 | vostok
# Processing Record 49 of Set 10 | belyy yar
# Processing Record 50 of Set 10 | sao jose da coroa grande
# Processing Record 1 of Set 11 | lewiston
# Processing Record 2 of Set 11 | gaozhou
# Processing Record 3 of Set 11 | poli
# Processing Record 4 of Set 11 | ostersund
# Processing Record 5 of Set 11 | olafsvik
# Processing Record 6 of Set 11 | nazas
# Processing Record 7 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 8 of Set 11 | tchibanga
# Processing Record 9 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 10 of Set 11 | jacareacanga
# Processing Record 11 of Set 11 | labrea
# Processing Record 12 of Set 11 | blackfoot
# Processing Record 13 of Set 11 | airai
# Processing Record 14 of Set 11 | taywarah
# Processing Record 15 of Set 11 | faanui
# Processing Record 16 of Set 11 | old orchard beach
# Processing Record 17 of Set 11 | segovia
# Processing Record 18 of Set 11 | plettenberg bay
# Processing Record 19 of Set 11 | varhaug
# Processing Record 20 of Set 11 | ariquemes
# Processing Record 21 of Set 11 | tual
# Processing Record 22 of Set 11 | saint-francois
# Processing Record 23 of Set 11 | hami
# Processing Record 24 of Set 11 | moose factory
# Processing Record 25 of Set 11 | sembakung
# Processing Record 26 of Set 11 | jiayuguan
# Processing Record 27 of Set 11 | miraflores
# Processing Record 28 of Set 11 | jurm
# Processing Record 29 of Set 11 | dumas
# Processing Record 30 of Set 11 | pascagoula
# Processing Record 31 of Set 11 | ketchikan
# Processing Record 32 of Set 11 | katsuura
# Processing Record 33 of Set 11 | kalabo
# Processing Record 34 of Set 11 | fez
# Processing Record 35 of Set 11 | te anau
# Processing Record 36 of Set 11 | mabaruma
# Processing Record 37 of Set 11 | summerside
# Processing Record 38 of Set 11 | gat
# Processing Record 39 of Set 11 | chabahar
# Processing Record 40 of Set 11 | port pirie
# Processing Record 41 of Set 11 | santa rita
# Processing Record 42 of Set 11 | kuala terengganu
# Processing Record 43 of Set 11 | werkendam
# Processing Record 44 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 11 | barcelos
# Processing Record 46 of Set 11 | winneba
# Processing Record 47 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 48 of Set 11 | bunia
# Processing Record 49 of Set 11 | thunder bay
# Processing Record 50 of Set 11 | nkowakowa
# Processing Record 1 of Set 12 | gospic
# Processing Record 2 of Set 12 | mankovo-kalitvenskoye
# City not found. Skipping...
# Processing Record 3 of Set 12 | asayita
# City not found. Skipping...
# Processing Record 4 of Set 12 | ferrol
# Processing Record 5 of Set 12 | mimongo
# Processing Record 6 of Set 12 | kavali
# Processing Record 7 of Set 12 | palana
# Processing Record 8 of Set 12 | saint-pierre
# Processing Record 9 of Set 12 | vila velha
# Processing Record 10 of Set 12 | mogilno
# Processing Record 11 of Set 12 | valparaiso
# Processing Record 12 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 13 of Set 12 | tombouctou
# Processing Record 14 of Set 12 | petrivka
# Processing Record 15 of Set 12 | muisne
# Processing Record 16 of Set 12 | haines junction
# Processing Record 17 of Set 12 | union
# Processing Record 18 of Set 12 | havelock
# Processing Record 19 of Set 12 | thaba-tseka
# Processing Record 20 of Set 12 | mwinilunga
# Processing Record 21 of Set 12 | roma
# Processing Record 22 of Set 12 | muros
# Processing Record 23 of Set 12 | coahuayana
# Processing Record 24 of Set 12 | odugathur
# City not found. Skipping...
# Processing Record 25 of Set 12 | bundibugyo
# Processing Record 26 of Set 12 | znamenskoye
# Processing Record 27 of Set 12 | gizo
# Processing Record 28 of Set 12 | nizhniy tsasuchey
# Processing Record 29 of Set 12 | iqaluit
# Processing Record 30 of Set 12 | balykshi
# Processing Record 31 of Set 12 | springdale
# Processing Record 32 of Set 12 | tepalcatepec
# Processing Record 33 of Set 12 | aklavik
# Processing Record 34 of Set 12 | rincon
# Processing Record 35 of Set 12 | jalpan
# Processing Record 36 of Set 12 | buin
# Processing Record 37 of Set 12 | dalmau
# Processing Record 38 of Set 12 | bubaque
# Processing Record 39 of Set 12 | sudak
# Processing Record 40 of Set 12 | zhezkazgan
# Processing Record 41 of Set 12 | almaznyy
# Processing Record 42 of Set 12 | mountain home
# Processing Record 43 of Set 12 | bestobe
# Processing Record 44 of Set 12 | selizharovo
# Processing Record 45 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 12 | ashqelon
# Processing Record 47 of Set 12 | psyzh
# Processing Record 48 of Set 12 | springfield
# Processing Record 49 of Set 12 | duz
# City not found. Skipping...
# Processing Record 50 of Set 12 | carahue
# Processing Record 1 of Set 13 | ventspils
# Processing Record 2 of Set 13 | weligama
# Processing Record 3 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 13 | tutoia
# Processing Record 5 of Set 13 | paamiut
# Processing Record 6 of Set 13 | hays
# Processing Record 7 of Set 13 | alice
# Processing Record 8 of Set 13 | kharp
# Processing Record 9 of Set 13 | luba
# Processing Record 10 of Set 13 | sinegorye
# Processing Record 11 of Set 13 | husavik
# Processing Record 12 of Set 13 | sungaipenuh
# Processing Record 13 of Set 13 | sterling
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Bredasdorp -34.5322   20.0403     48.27        93         100
# 1  Port Elizabeth -33.9180   25.5701     53.10        87         100
# 2     Provideniya  64.3833 -173.3000     50.11        81          90
# 3          Baykit  61.6700   96.3700     58.08        91          99
# 4       Upernavik  72.7868  -56.1549     40.96        98         100
# 5            Kaeo -35.1000  173.7833     60.33        77          60
# 6         Ushuaia -54.8000  -68.3000     37.06        87          40
# 7        Tasiilaq  65.6145  -37.6368     41.16        97         100
# 8        Pochutla  15.7432  -96.4661     83.25        89          97
# 9            Lebu -37.6167  -73.6500     52.02        92          91
#
#    Wind Speed Country                 Date
# 0        5.86      ZA  2021-07-20 03:10:10
# 1        8.39      ZA  2021-07-20 03:10:10
# 2        8.95      RU  2021-07-20 03:05:55
# 3        5.28      RU  2021-07-20 03:10:11
# 4        8.08      GL  2021-07-20 03:10:11
# 5        7.23      NZ  2021-07-20 03:10:12
# 6        2.30      AR  2021-07-20 03:10:12
# 7        8.88      GL  2021-07-20 03:05:40
# 8        4.59      MX  2021-07-20 03:10:13
# 9        9.93      CL  2021-07-20 03:10:13

# %%
city_data_df = city_data_df[['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']].sort_index(ascending=True)
city_data_df
# Out:
#                City Country                 Date      Lat       Lng  Max Temp  \
# 0        Bredasdorp      ZA  2021-07-20 03:10:10 -34.5322   20.0403     48.27
# 1    Port Elizabeth      ZA  2021-07-20 03:10:10 -33.9180   25.5701     53.10
# 2       Provideniya      RU  2021-07-20 03:05:55  64.3833 -173.3000     50.11
# 3            Baykit      RU  2021-07-20 03:10:11  61.6700   96.3700     58.08
# 4         Upernavik      GL  2021-07-20 03:10:11  72.7868  -56.1549     40.96
# ..              ...     ...                  ...      ...       ...       ...
# 552            Luba      GQ  2021-07-20 03:14:50   3.4568    8.5547     77.14
# 553       Sinegorye      RU  2021-07-20 03:14:51  62.0788  150.4770     77.38
# 554         Husavik      IS  2021-07-20 03:14:51  66.0449  -17.3389     53.11
# 555     Sungaipenuh      ID  2021-07-20 03:10:06  -2.0833  101.3833     72.54
# 556        Sterling      US  2021-07-20 03:14:07  39.0062  -77.4286     78.28
#
#      Humidity  Cloudiness  Wind Speed
# 0          93         100        5.86
# 1          87         100        8.39
# 2          81          90        8.95
# 3          91          99        5.28
# 4          98         100        8.08
# ..        ...         ...         ...
# 552        87          99       12.62
# 553        22          43        5.95
# 554        82          15        3.36
# 555        66         100        1.21
# 556        81           1        4.61
#
# [557 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
